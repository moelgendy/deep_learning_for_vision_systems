# %% [markdown]
# # Computer Vision Tutorial
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255
# In fact, the cost function has the shape of a bowl, but it can be an elongated bowl if the features have very
# different scales. Figure below shows Gradient Descent on a training set where features 1 and 2 have the
# same scale (on the left), and on a training set where feature 1 has much smaller values than feature 2 (on
# the right).
#
# ** Tip: ** When using Gradient Descent, you should ensure that all features have a similar scale to speed up training or else it will take much longer to converge.
#
# ![feature scaling](normalized.jpg)

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture
#
# ![feature scaling](cnn-schema1.jpg)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, save_best_only=True)

hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 19s - loss: 1.6015 - accuracy: 0.4201 - val_loss: 1.4069 - val_accuracy: 0.4974
#
# Epoch 00001: val_loss improved from inf to 1.40692, saving model to model.weights.best.hdf5
# Epoch 2/100
#  - 26s - loss: 1.2940 - accuracy: 0.5354 - val_loss: 1.1676 - val_accuracy: 0.5960
#
# Epoch 00002: val_loss improved from 1.40692 to 1.16764, saving model to model.weights.best.hdf5
# Epoch 3/100
#  - 27s - loss: 1.1701 - accuracy: 0.5862 - val_loss: 1.1453 - val_accuracy: 0.5996
#
# Epoch 00003: val_loss improved from 1.16764 to 1.14532, saving model to model.weights.best.hdf5
# Epoch 4/100
#  - 29s - loss: 1.0884 - accuracy: 0.6146 - val_loss: 1.0601 - val_accuracy: 0.6232
#
# Epoch 00004: val_loss improved from 1.14532 to 1.06011, saving model to model.weights.best.hdf5
# Epoch 5/100
#  - 28s - loss: 1.0522 - accuracy: 0.6304 - val_loss: 1.0739 - val_accuracy: 0.6268
#
# Epoch 00005: val_loss did not improve from 1.06011
# Epoch 6/100
#  - 29s - loss: 1.0232 - accuracy: 0.6437 - val_loss: 0.9668 - val_accuracy: 0.6626
#
# Epoch 00006: val_loss improved from 1.06011 to 0.96683, saving model to model.weights.best.hdf5
# Epoch 7/100
#  - 30s - loss: 1.0141 - accuracy: 0.6500 - val_loss: 1.1182 - val_accuracy: 0.6114
#
# Epoch 00007: val_loss did not improve from 0.96683
# Epoch 8/100
#  - 29s - loss: 1.0096 - accuracy: 0.6526 - val_loss: 0.9595 - val_accuracy: 0.6762
#
# Epoch 00008: val_loss improved from 0.96683 to 0.95946, saving model to model.weights.best.hdf5
# Epoch 9/100
#  - 31s - loss: 1.0088 - accuracy: 0.6552 - val_loss: 0.9655 - val_accuracy: 0.6728
#
# Epoch 00009: val_loss did not improve from 0.95946
# Epoch 10/100
#  - 31s - loss: 1.0156 - accuracy: 0.6583 - val_loss: 1.1407 - val_accuracy: 0.6328
#
# Epoch 00010: val_loss did not improve from 0.95946
# Epoch 11/100
#  - 31s - loss: 1.0358 - accuracy: 0.6504 - val_loss: 1.0881 - val_accuracy: 0.6446
#
# Epoch 00011: val_loss did not improve from 0.95946
# Epoch 12/100
#  - 31s - loss: 1.0408 - accuracy: 0.6496 - val_loss: 1.0260 - val_accuracy: 0.6764
#
# Epoch 00012: val_loss did not improve from 0.95946
# Epoch 13/100
#  - 29s - loss: 1.0596 - accuracy: 0.6456 - val_loss: 1.3742 - val_accuracy: 0.5936
#
# Epoch 00013: val_loss did not improve from 0.95946
# Epoch 14/100
#  - 31s - loss: 1.0798 - accuracy: 0.6389 - val_loss: 0.9666 - val_accuracy: 0.6792
#
# Epoch 00014: val_loss did not improve from 0.95946
# Epoch 15/100
#  - 30s - loss: 1.1017 - accuracy: 0.6326 - val_loss: 1.0361 - val_accuracy: 0.6588
#
# Epoch 00015: val_loss did not improve from 0.95946
# Epoch 16/100
#  - 28s - loss: 1.1310 - accuracy: 0.6233 - val_loss: 0.9777 - val_accuracy: 0.6642
#
# Epoch 00016: val_loss did not improve from 0.95946
# Epoch 17/100
#  - 30s - loss: 1.1412 - accuracy: 0.6197 - val_loss: 1.4206 - val_accuracy: 0.5566
#
# Epoch 00017: val_loss did not improve from 0.95946
# Epoch 18/100
#  - 32s - loss: 1.1634 - accuracy: 0.6141 - val_loss: 1.0382 - val_accuracy: 0.6518
#
# Epoch 00018: val_loss did not improve from 0.95946
# Epoch 19/100
#  - 32s - loss: 1.1687 - accuracy: 0.6117 - val_loss: 0.9625 - val_accuracy: 0.6740
#
# Epoch 00019: val_loss did not improve from 0.95946
# Epoch 20/100
#  - 33s - loss: 1.1869 - accuracy: 0.6052 - val_loss: 1.2483 - val_accuracy: 0.5690
#
# Epoch 00020: val_loss did not improve from 0.95946
# Epoch 21/100
#  - 31s - loss: 1.2146 - accuracy: 0.5986 - val_loss: 1.1205 - val_accuracy: 0.6362
#
# Epoch 00021: val_loss did not improve from 0.95946
# Epoch 22/100
#  - 32s - loss: 1.2308 - accuracy: 0.5946 - val_loss: 1.8760 - val_accuracy: 0.5728
#
# Epoch 00022: val_loss did not improve from 0.95946
# Epoch 23/100
#  - 33s - loss: 1.2509 - accuracy: 0.5866 - val_loss: 1.0727 - val_accuracy: 0.6474
#
# Epoch 00023: val_loss did not improve from 0.95946
# Epoch 24/100
#  - 30s - loss: 1.2748 - accuracy: 0.5809 - val_loss: 1.2471 - val_accuracy: 0.6178
#
# Epoch 00024: val_loss did not improve from 0.95946
# Epoch 25/100
#  - 32s - loss: 1.2943 - accuracy: 0.5729 - val_loss: 1.1763 - val_accuracy: 0.5866
#
# Epoch 00025: val_loss did not improve from 0.95946
# Epoch 26/100
#  - 32s - loss: 1.3191 - accuracy: 0.5650 - val_loss: 1.2109 - val_accuracy: 0.5822
#
# Epoch 00026: val_loss did not improve from 0.95946
# Epoch 27/100
#  - 32s - loss: 1.3203 - accuracy: 0.5653 - val_loss: 1.1476 - val_accuracy: 0.5986
#
# Epoch 00027: val_loss did not improve from 0.95946
# Epoch 28/100
#  - 33s - loss: 1.3677 - accuracy: 0.5476 - val_loss: 1.0794 - val_accuracy: 0.6366
#
# Epoch 00028: val_loss did not improve from 0.95946
# Epoch 29/100
#  - 33s - loss: 1.3874 - accuracy: 0.5428 - val_loss: 1.1810 - val_accuracy: 0.6198
#
# Epoch 00029: val_loss did not improve from 0.95946
# Epoch 30/100
#  - 31s - loss: 1.3873 - accuracy: 0.5397 - val_loss: 1.9794 - val_accuracy: 0.6152
#
# Epoch 00030: val_loss did not improve from 0.95946
# Epoch 31/100
#  - 31s - loss: 1.4119 - accuracy: 0.5348 - val_loss: 1.2645 - val_accuracy: 0.5712
#
# Epoch 00031: val_loss did not improve from 0.95946
# Epoch 32/100
#  - 32s - loss: 1.4433 - accuracy: 0.5255 - val_loss: 1.3010 - val_accuracy: 0.5624
#
# Epoch 00032: val_loss did not improve from 0.95946
# Epoch 33/100
#  - 33s - loss: 1.4655 - accuracy: 0.5135 - val_loss: 1.3680 - val_accuracy: 0.5504
#
# Epoch 00033: val_loss did not improve from 0.95946
# Epoch 34/100
#  - 34s - loss: 1.4580 - accuracy: 0.5134 - val_loss: 2.7588 - val_accuracy: 0.3882
#
# Epoch 00034: val_loss did not improve from 0.95946
# Epoch 35/100
#  - 30s - loss: 1.4661 - accuracy: 0.5094 - val_loss: 1.3365 - val_accuracy: 0.5730
#
# Epoch 00035: val_loss did not improve from 0.95946
# Epoch 36/100
#  - 29s - loss: 1.4772 - accuracy: 0.5095 - val_loss: 1.2845 - val_accuracy: 0.5764
#
# Epoch 00036: val_loss did not improve from 0.95946
# Epoch 37/100
#  - 34s - loss: 1.5072 - accuracy: 0.4991 - val_loss: 2.2538 - val_accuracy: 0.4612
#
# Epoch 00037: val_loss did not improve from 0.95946
# Epoch 38/100
#  - 32s - loss: 1.5287 - accuracy: 0.4905 - val_loss: 1.3181 - val_accuracy: 0.5376
#
# Epoch 00038: val_loss did not improve from 0.95946
# Epoch 39/100
#  - 34s - loss: 1.5378 - accuracy: 0.4859 - val_loss: 1.6776 - val_accuracy: 0.4762
#
# Epoch 00039: val_loss did not improve from 0.95946
# Epoch 40/100
#  - 30s - loss: 1.5409 - accuracy: 0.4856 - val_loss: 1.1572 - val_accuracy: 0.6174
#
# Epoch 00040: val_loss did not improve from 0.95946
# Epoch 41/100
#  - 31s - loss: 1.5621 - accuracy: 0.4763 - val_loss: 1.3028 - val_accuracy: 0.5730
#
# Epoch 00041: val_loss did not improve from 0.95946
# Epoch 42/100
#  - 32s - loss: 1.5765 - accuracy: 0.4706 - val_loss: 1.3421 - val_accuracy: 0.5600
#
# Epoch 00042: val_loss did not improve from 0.95946
# Epoch 43/100
#  - 35s - loss: 1.5705 - accuracy: 0.4692 - val_loss: 1.4173 - val_accuracy: 0.5116
#
# Epoch 00043: val_loss did not improve from 0.95946
# Epoch 44/100
#  - 31s - loss: 1.5928 - accuracy: 0.4649 - val_loss: 1.3637 - val_accuracy: 0.5156
#
# Epoch 00044: val_loss did not improve from 0.95946
# Epoch 45/100
#  - 33s - loss: 1.5876 - accuracy: 0.4615 - val_loss: 1.5125 - val_accuracy: 0.4572
#
# Epoch 00045: val_loss did not improve from 0.95946
# Epoch 46/100
#  - 32s - loss: 1.5921 - accuracy: 0.4624 - val_loss: 1.3226 - val_accuracy: 0.5248
#
# Epoch 00046: val_loss did not improve from 0.95946
# Epoch 47/100
#  - 32s - loss: 1.5919 - accuracy: 0.4591 - val_loss: 1.4000 - val_accuracy: 0.5264
#
# Epoch 00047: val_loss did not improve from 0.95946
# Epoch 48/100
#  - 32s - loss: 1.6000 - accuracy: 0.4611 - val_loss: 1.3062 - val_accuracy: 0.5592
#
# Epoch 00048: val_loss did not improve from 0.95946
# Epoch 49/100
#  - 31s - loss: 1.5949 - accuracy: 0.4632 - val_loss: 1.4506 - val_accuracy: 0.5254
#
# Epoch 00049: val_loss did not improve from 0.95946
# Epoch 50/100
#  - 31s - loss: 1.5990 - accuracy: 0.4590 - val_loss: 1.2829 - val_accuracy: 0.5706
#
# Epoch 00050: val_loss did not improve from 0.95946
# Epoch 51/100
#  - 34s - loss: 1.5957 - accuracy: 0.4571 - val_loss: 1.4437 - val_accuracy: 0.5124
#
# Epoch 00051: val_loss did not improve from 0.95946
# Epoch 52/100
#  - 29s - loss: 1.6094 - accuracy: 0.4526 - val_loss: 2.5743 - val_accuracy: 0.4180
#
# Epoch 00052: val_loss did not improve from 0.95946
# Epoch 53/100
#  - 31s - loss: 1.6250 - accuracy: 0.4528 - val_loss: 1.6294 - val_accuracy: 0.4852
#
# Epoch 00053: val_loss did not improve from 0.95946
# Epoch 54/100
#  - 35s - loss: 1.6228 - accuracy: 0.4469 - val_loss: 1.4729 - val_accuracy: 0.5004
# Epoch 00054: val_loss did not improve from 0.95946
# Epoch 55/100
#  - 34s - loss: 1.6241 - accuracy: 0.4488 - val_loss: 1.3547 - val_accuracy: 0.5492
#
# Epoch 00055: val_loss did not improve from 0.95946
# Epoch 56/100
#  - 37s - loss: 1.6416 - accuracy: 0.4381 - val_loss: 1.4537 - val_accuracy: 0.5268
#
# Epoch 00056: val_loss did not improve from 0.95946
# Epoch 57/100
#  - 32s - loss: 1.6486 - accuracy: 0.4444 - val_loss: 1.3352 - val_accuracy: 0.5156
#
# Epoch 00057: val_loss did not improve from 0.95946
# Epoch 58/100
#  - 32s - loss: 1.6412 - accuracy: 0.4394 - val_loss: 1.6509 - val_accuracy: 0.4496
#
# Epoch 00058: val_loss did not improve from 0.95946
# Epoch 59/100
#  - 34s - loss: 1.6466 - accuracy: 0.4385 - val_loss: 1.2979 - val_accuracy: 0.5360
#
# Epoch 00059: val_loss did not improve from 0.95946
# Epoch 60/100
#  - 35s - loss: 1.6436 - accuracy: 0.4405 - val_loss: 1.7320 - val_accuracy: 0.4478
#
# Epoch 00060: val_loss did not improve from 0.95946
# Epoch 61/100
#  - 35s - loss: 1.6522 - accuracy: 0.4318 - val_loss: 1.4831 - val_accuracy: 0.4714
#
# Epoch 00061: val_loss did not improve from 0.95946
# Epoch 62/100
#  - 35s - loss: 1.6567 - accuracy: 0.4323 - val_loss: 1.4481 - val_accuracy: 0.4840
#
# Epoch 00062: val_loss did not improve from 0.95946
# Epoch 63/100
#  - 31s - loss: 1.6432 - accuracy: 0.4362 - val_loss: 1.3969 - val_accuracy: 0.5154
#
# Epoch 00063: val_loss did not improve from 0.95946
# Epoch 64/100
#  - 34s - loss: 1.6586 - accuracy: 0.4317 - val_loss: 1.3445 - val_accuracy: 0.5238
#
# Epoch 00064: val_loss did not improve from 0.95946
# Epoch 65/100
#  - 40s - loss: 1.6594 - accuracy: 0.4302 - val_loss: 1.4732 - val_accuracy: 0.4870
#
# Epoch 00065: val_loss did not improve from 0.95946
# Epoch 66/100
#  - 34s - loss: 1.6658 - accuracy: 0.4282 - val_loss: 1.5339 - val_accuracy: 0.4570
#
# Epoch 00066: val_loss did not improve from 0.95946
# Epoch 67/100
#  - 37s - loss: 1.6742 - accuracy: 0.4267 - val_loss: 2.0799 - val_accuracy: 0.4128
#
# Epoch 00067: val_loss did not improve from 0.95946
# Epoch 68/100
#  - 38s - loss: 1.6703 - accuracy: 0.4269 - val_loss: 1.5151 - val_accuracy: 0.5122
#
# Epoch 00068: val_loss did not improve from 0.95946
# Epoch 69/100
#  - 36s - loss: 1.6770 - accuracy: 0.4246 - val_loss: 1.3719 - val_accuracy: 0.5072
#
# Epoch 00069: val_loss did not improve from 0.95946
# Epoch 70/100
#  - 35s - loss: 1.6778 - accuracy: 0.4227 - val_loss: 1.9032 - val_accuracy: 0.3876
#
# Epoch 00070: val_loss did not improve from 0.95946
# Epoch 71/100
#  - 38s - loss: 1.6843 - accuracy: 0.4166 - val_loss: 1.7123 - val_accuracy: 0.3626
#
# Epoch 00071: val_loss did not improve from 0.95946
# Epoch 72/100
#  - 36s - loss: 1.6936 - accuracy: 0.4172 - val_loss: 1.4914 - val_accuracy: 0.4828
#
# Epoch 00072: val_loss did not improve from 0.95946
# Epoch 73/100
#  - 38s - loss: 1.6973 - accuracy: 0.4132 - val_loss: 1.4718 - val_accuracy: 0.4802
#
# Epoch 00073: val_loss did not improve from 0.95946
# Epoch 74/100
#  - 36s - loss: 1.6873 - accuracy: 0.4172 - val_loss: 1.6286 - val_accuracy: 0.4030
#
# Epoch 00074: val_loss did not improve from 0.95946
# Epoch 75/100
#  - 36s - loss: 1.7207 - accuracy: 0.4053 - val_loss: 1.4199 - val_accuracy: 0.4972
#
# Epoch 00075: val_loss did not improve from 0.95946
# Epoch 76/100
#  - 40s - loss: 1.7104 - accuracy: 0.4070 - val_loss: 1.3357 - val_accuracy: 0.5134
#
# Epoch 00076: val_loss did not improve from 0.95946
# Epoch 77/100
#  - 33s - loss: 1.7164 - accuracy: 0.4055 - val_loss: 1.5342 - val_accuracy: 0.4040
#
# Epoch 00077: val_loss did not improve from 0.95946
# Epoch 78/100
#  - 35s - loss: 1.7313 - accuracy: 0.3983 - val_loss: 2.0577 - val_accuracy: 0.3986
#
# Epoch 00078: val_loss did not improve from 0.95946
# Epoch 79/100
#  - 36s - loss: 1.7214 - accuracy: 0.4034 - val_loss: 1.5756 - val_accuracy: 0.4560
#
# Epoch 00079: val_loss did not improve from 0.95946
# Epoch 80/100
#  - 36s - loss: 1.7107 - accuracy: 0.4041 - val_loss: 1.4652 - val_accuracy: 0.4606
#
# Epoch 00080: val_loss did not improve from 0.95946
# Epoch 81/100
#  - 37s - loss: 1.7246 - accuracy: 0.4006 - val_loss: 1.7873 - val_accuracy: 0.3900
#
# Epoch 00081: val_loss did not improve from 0.95946
# Epoch 82/100
#  - 33s - loss: 1.7121 - accuracy: 0.4041 - val_loss: 1.3913 - val_accuracy: 0.5088
#
# Epoch 00082: val_loss did not improve from 0.95946
# Epoch 83/100
#  - 37s - loss: 1.7198 - accuracy: 0.4018 - val_loss: 1.5795 - val_accuracy: 0.4464
#
# Epoch 00083: val_loss did not improve from 0.95946
# Epoch 84/100
#  - 38s - loss: 1.7291 - accuracy: 0.3957 - val_loss: 1.5632 - val_accuracy: 0.4438
#
# Epoch 00084: val_loss did not improve from 0.95946
# Epoch 85/100
#  - 35s - loss: 1.7276 - accuracy: 0.3968 - val_loss: 1.4471 - val_accuracy: 0.4778
#
# Epoch 00085: val_loss did not improve from 0.95946
# Epoch 86/100
#  - 34s - loss: 1.7218 - accuracy: 0.3997 - val_loss: 1.6796 - val_accuracy: 0.4228
#
# Epoch 00086: val_loss did not improve from 0.95946
# Epoch 87/100
#  - 36s - loss: 1.7402 - accuracy: 0.3929 - val_loss: 1.6260 - val_accuracy: 0.4304
#
# Epoch 00087: val_loss did not improve from 0.95946
# Epoch 88/100
#  - 28s - loss: 1.7355 - accuracy: 0.3928 - val_loss: 1.5761 - val_accuracy: 0.4582
#
# Epoch 00088: val_loss did not improve from 0.95946
# Epoch 89/100
#  - 35s - loss: 1.7442 - accuracy: 0.3905 - val_loss: 1.4195 - val_accuracy: 0.4994
#
# Epoch 00089: val_loss did not improve from 0.95946
# Epoch 90/100
#  - 33s - loss: 1.7473 - accuracy: 0.3863 - val_loss: 1.7769 - val_accuracy: 0.4528
#
# Epoch 00090: val_loss did not improve from 0.95946
# Epoch 91/100
#  - 33s - loss: 1.7549 - accuracy: 0.3851 - val_loss: 1.4806 - val_accuracy: 0.4368
#
# Epoch 00091: val_loss did not improve from 0.95946
# Epoch 92/100
#  - 31s - loss: 1.7606 - accuracy: 0.3817 - val_loss: 1.5985 - val_accuracy: 0.3964
#
# Epoch 00092: val_loss did not improve from 0.95946
# Epoch 93/100
#  - 38s - loss: 1.7684 - accuracy: 0.3788 - val_loss: 1.5822 - val_accuracy: 0.4430
#
# Epoch 00093: val_loss did not improve from 0.95946
# Epoch 94/100
#  - 38s - loss: 1.7665 - accuracy: 0.3759 - val_loss: 1.4803 - val_accuracy: 0.4786
#
# Epoch 00094: val_loss did not improve from 0.95946
# Epoch 95/100
#  - 39s - loss: 1.7769 - accuracy: 0.3790 - val_loss: 1.6669 - val_accuracy: 0.4130
#
# Epoch 00095: val_loss did not improve from 0.95946
# Epoch 96/100
#  - 32s - loss: 1.8018 - accuracy: 0.3701 - val_loss: 2.1743 - val_accuracy: 0.3332
#
# Epoch 00096: val_loss did not improve from 0.95946
# Epoch 97/100
#  - 35s - loss: 1.7893 - accuracy: 0.3696 - val_loss: 1.5678 - val_accuracy: 0.4510
#
# Epoch 00097: val_loss did not improve from 0.95946
# Epoch 98/100
#  - 35s - loss: 1.7731 - accuracy: 0.3730 - val_loss: 1.5928 - val_accuracy: 0.4282
#
# Epoch 00098: val_loss did not improve from 0.95946
# Epoch 99/100
#  - 35s - loss: 1.7888 - accuracy: 0.3665 - val_loss: 1.4975 - val_accuracy: 0.4394
#
# Epoch 00099: val_loss did not improve from 0.95946
# Epoch 100/100
#  - 39s - loss: 1.7915 - accuracy: 0.3675 - val_loss: 2.0238 - val_accuracy: 0.3456
#
# Epoch 00100: val_loss did not improve from 0.95946

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6620000004768372

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
